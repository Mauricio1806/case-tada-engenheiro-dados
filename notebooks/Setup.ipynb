# %%
STORAGE_ACCOUNT = 'stccasemauricioes'
CONTAINER = 'data'
STORAGE_KEY = 'COLOCAR_CHAVE_AQUI'

spark.conf.set("fs.azure.account.key." + STORAGE_ACCOUNT + ".blob.core.windows.net", STORAGE_KEY)

caminho = "wasbs://" + CONTAINER + "@" + STORAGE_ACCOUNT + ".blob.core.windows.net/raw_data/"
display(dbutils.fs.ls(caminho))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>wasbs://data@stccasemauricioes.blob.core.windows.net/raw_data/clientes.csv</td><td>clientes.csv</td><td>141938</td><td>1779028675000</td></tr><tr><td>wasbs://data@stccasemauricioes.blob.core.windows.net/raw_data/lojas.csv</td><td>lojas.csv</td><td>505</td><td>1779028675000</td></tr><tr><td>wasbs://data@stccasemauricioes.blob.core.windows.net/raw_data/pagamentos.csv</td><td>pagamentos.csv</td><td>323470</td><td>1779028675000</td></tr><tr><td>wasbs://data@stccasemauricioes.blob.core.windows.net/raw_data/pedido_itens.csv</td><td>pedido_itens.csv</td><td>535396</td><td>1779028675000</td></tr><tr><td>wasbs://data@stccasemauricioes.blob.core.windows.net/raw_data/pedidos.csv</td><td>pedidos.csv</td><td>385892</td><td>1779028675000</td></tr><tr><td>wasbs://data@stccasemauricioes.blob.core.windows.net/raw_data/produtos.csv</td><td>produtos.csv</td><td>876</td><td>1779028675000</td></tr></tbody></table></div>
